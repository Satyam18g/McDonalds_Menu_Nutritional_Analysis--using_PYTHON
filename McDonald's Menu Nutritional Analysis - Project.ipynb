# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# %%
df=pd.read_csv("Nutrical Dataset.csv")

# %%
df.sample()
# Out:
#      Category                   Item     Serving Size  Calories  \
# 105  Desserts  Oatmeal Raisin Cookie  1 cookie (33 g)       150
#
#      Calories from Fat  Total Fat  Total Fat (% Daily Value)  Saturated Fat  \
# 105                 50        6.0                          9            2.5
#
#      Saturated Fat (% Daily Value)  Trans Fat  ...  Carbohydrates  \
# 105                             13        0.0  ...             22
#
#      Carbohydrates (% Daily Value)  Dietary Fiber  \
# 105                              7              1
#
#      Dietary Fiber (% Daily Value)  Sugars  Protein  \
# 105                              3      13        2
#
#      Vitamin A (% Daily Value)  Vitamin C (% Daily Value)  \
# 105                          2                          0
#
#      Calcium (% Daily Value)  Iron (% Daily Value)
# 105                        2                     6
#
# [1 rows x 24 columns]

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Category                          object
# Item                              object
# Serving Size                      object
# Calories                           int64
# Calories from Fat                  int64
# Total Fat                        float64
# Total Fat (% Daily Value)          int64
# Saturated Fat                    float64
# Saturated Fat (% Daily Value)      int64
# Trans Fat                        float64
# Cholesterol                        int64
# Cholesterol (% Daily Value)        int64
# Sodium                             int64
# Sodium (% Daily Value)             int64
# Carbohydrates                      int64
# Carbohydrates (% Daily Value)      int64
# Dietary Fiber                      int64
# Dietary Fiber (% Daily Value)      int64
# Sugars                             int64
# Protein                            int64
# Vitamin A (% Daily Value)          int64
# Vitamin C (% Daily Value)          int64
# Calcium (% Daily Value)            int64
# ...

# %%
df.isnull().sum()
# Out:
# Category                         0
# Item                             0
# Serving Size                     0
# Calories                         0
# Calories from Fat                0
# Total Fat                        0
# Total Fat (% Daily Value)        0
# Saturated Fat                    0
# Saturated Fat (% Daily Value)    0
# Trans Fat                        0
# Cholesterol                      0
# Cholesterol (% Daily Value)      0
# Sodium                           0
# Sodium (% Daily Value)           0
# Carbohydrates                    0
# Carbohydrates (% Daily Value)    0
# Dietary Fiber                    0
# Dietary Fiber (% Daily Value)    0
# Sugars                           0
# Protein                          0
# Vitamin A (% Daily Value)        0
# Vitamin C (% Daily Value)        0
# Calcium (% Daily Value)          0
# Iron (% Daily Value)             0
# dtype: int64

# %%
df.nunique()
# Out:
# Category                           9
# Item                             260
# Serving Size                     107
# Calories                          78
# Calories from Fat                 48
# Total Fat                         52
# Total Fat (% Daily Value)         63
# Saturated Fat                     26
# Saturated Fat (% Daily Value)     74
# Trans Fat                          5
# Cholesterol                       35
# Cholesterol (% Daily Value)       48
# Sodium                           111
# Sodium (% Daily Value)            65
# Carbohydrates                     84
# Carbohydrates (% Daily Value)     40
# Dietary Fiber                      8
# Dietary Fiber (% Daily Value)     24
# Sugars                            83
# Protein                           42
# Vitamin A (% Daily Value)         19
# Vitamin C (% Daily Value)         17
# Calcium (% Daily Value)           16
# Iron (% Daily Value)              12
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 260 entries, 0 to 259
# Data columns (total 24 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Category                       260 non-null    object
#  1   Item                           260 non-null    object
#  2   Serving Size                   260 non-null    object
#  3   Calories                       260 non-null    int64
#  4   Calories from Fat              260 non-null    int64
#  5   Total Fat                      260 non-null    float64
#  6   Total Fat (% Daily Value)      260 non-null    int64
#  7   Saturated Fat                  260 non-null    float64
#  8   Saturated Fat (% Daily Value)  260 non-null    int64
#  9   Trans Fat                      260 non-null    float64
#  10  Cholesterol                    260 non-null    int64
#  11  Cholesterol (% Daily Value)    260 non-null    int64
# ...

# %%
len(df)
# Out:
# 260

# %%
df.columns
# Out:
# Index(['Category', 'Item', 'Serving Size', 'Calories', 'Calories from Fat',
#        'Total Fat', 'Total Fat (% Daily Value)', 'Saturated Fat',
#        'Saturated Fat (% Daily Value)', 'Trans Fat', 'Cholesterol',
#        'Cholesterol (% Daily Value)', 'Sodium', 'Sodium (% Daily Value)',
#        'Carbohydrates', 'Carbohydrates (% Daily Value)', 'Dietary Fiber',
#        'Dietary Fiber (% Daily Value)', 'Sugars', 'Protein',
#        'Vitamin A (% Daily Value)', 'Vitamin C (% Daily Value)',
#        'Calcium (% Daily Value)', 'Iron (% Daily Value)'],
#       dtype='object')

# %%
len(df.columns)
# Out:
# 24

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='Calories',data=df,color='lightsalmon',bins=20)
plt.show()

# %% [markdown]
# ### Most menu items have a calorie count within the range (188 to 282)

# %%
plt.figure(figsize=(15,5))
sns.histplot(x='Sugars',data=df,color='#ffff80',bins=16)
plt.show()

# %% [markdown]
# ### Most menu items have a sugar level within the range (0 to 8)

# %%
max_fat=df.sort_values('Total Fat').tail(10)

plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Total Fat',data=max_fat,hue='Item')
plt.show()

# %% [markdown]
# ### Item named Chicken McNuggets(40 piece) has highest fat value

# %%
max_protein=df.sort_values('Protein').tail(10)
plt.figure(figsize=(10,6))
sns.barplot(y='Item',x='Total Fat',data=max_protein,hue='Item')
plt.show()

# %% [markdown]
# ### Item named Chicken McNuggets(40 piece) has highest protein value

# %%
max_carb=df.sort_values('Carbohydrates').tail(10)
plt.figure(figsize=(10,4))
sns.barplot(y='Item',x='Total Fat',data=max_carb,hue='Item')
plt.show()

# %% [markdown]
#  ### Item named Chicken McNuggets(40 piece) has highest carbohydrates value

# %%
plt.figure(figsize=(8,3))
sns.barplot(y='Category',x='Vitamin A (% Daily Value)',data=df,hue='Category')
plt.show()

# %% [markdown]
# ### Salads are rich in Vitamin A whereas Beverages are poor source of Vitamin A

# %%
plt.figure(figsize=(8,3))
sns.barplot(y='Category',x='Iron (% Daily Value)',data=df,hue='Category')
plt.show()

# %% [markdown]
# ### Beef and Porks are rich in Iron whereas Beverages are poor source of Iron

# %%
plt.figure(figsize=(8,3))
sns.barplot(y='Category',x='Protein',data=df,hue='Category')
plt.show()

# %% [markdown]
# ### Chicken & Fish are rich in Protein whereas Beverages are good for low protein diet

# %%
plt.figure(figsize=(10,3))
sns.boxplot(y='Cholesterol',hue='Category',data=df)
plt.legend(ncols=df['Category'].nunique()/3)
plt.show()

# %%
col=df.select_dtypes(exclude='object').columns
Q1 = df[col].quantile(0.25)
Q3 = df[col].quantile(0.75)
IQR = Q3 - Q1
df = df[~((df[col] < (Q1 - 1.5*IQR))| (df[col] > (Q3 + 1.5*IQR))).any(axis=1)]


# Total number of records after removing the outliers
len(df)
# Out:
# 154

# %% [markdown]
# ## Recommendations for Improving the Nutritional Profile of McDonald's Menu
#
# ### 1. Increase Availability of Healthier Options
# - **Expand Salad and Fresh Vegetable Offerings:** Introduce more salads and vegetable-based dishes. Ensure these items are not only nutritious but also flavorful to attract more customers.
# - **Incorporate Whole Grains:** Use whole grain buns, tortillas, and wraps instead of refined grains to increase fiber content and improve overall nutritional value.
#
# ### 2. Modify Existing Menu Items
# - **Reduce Sodium Content:** Gradually lower the sodium levels in popular items to meet dietary guidelines without compromising taste.
# - **Lower Saturated Fats:** Use healthier cooking oils with lower saturated fat content and explore alternative cooking methods like grilling instead of frying.
#
# ### 3. Introduce Nutrient-Dense Ingredients
# - **Lean Protein Sources:** Offer more menu items with lean protein options like grilled chicken, fish, and plant-based proteins.
# - **Healthy Fats:** Incorporate sources of healthy fats such as avocados, nuts, and seeds into menu items.
#
# ### 4. Reformulate Recipes
# - **Cut Down on Added Sugars:** Reduce the amount of added sugars in sauces, dressings, and beverages. Introduce lower-sugar or no-sugar-added versions of popular items.
# - **Portion Control:** Offer smaller portion sizes for high-calorie items and provide clear information on calorie counts to help customers make informed choices.
#
# ### 5. Enhance Transparency and Education
# - **Nutritional Information Accessibility:** Ensure that nutritional information is easily accessible on menus, both in-store and online, so customers can make informed decisions.
# - **Health Campaigns:** Launch campaigns to educate customers about the benefits of healthier eating and how to make healthier choices at McDonald's.
#
# ### 6. Sustainable and Nutritious Ingredients
# - **Local and Organic Produce:** Source ingredients locally and consider using organic produce to improve the nutritional profile and support sustainability.
# - **Plant-Based Alternatives:** Expand the range of plant-based menu options to cater to the growing demand for vegetarian and vegan choices.
#
# ### 7. Customer Feedback and Continuous Improvement
# - **Regularly Update the Menu:** Regularly review and update the menu based on customer feedback and emerging nutritional research.
# - **Pilot Healthier Options:** Test healthier menu items in select locations to gauge customer response before rolling them out nationwide.
#
# By implementing these recommendations, McDonald's can enhance the nutritional quality of their menu, appeal to health-conscious consumers, and contribute positively to public health.
